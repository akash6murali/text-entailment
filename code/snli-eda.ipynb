# %%
from snli_data_explorer import SNLIExplorer

# %%
explorer = SNLIExplorer("/Users/akashmurali/Documents/NLP/project/snli_1.0")
explorer.comprehensive_analysis()
# Out:
# 🔍 COMPREHENSIVE SNLI DATASET ANALYSIS
# ...
# 📊 BASIC DATASET STATISTICS
# ...
# Loading train data from /Users/akashmurali/Documents/NLP/project/snli_1.0/snli_1.0_train.jsonl...
# ✅ Loaded 550152 examples from train split
#
# TRAIN SET:
#   Total examples: 550,152
#   Valid examples: 549,367
#   Invalid examples: 785
#   Label distribution:
#          neutral: 182,764 ( 33.3%)
#     contradiction: 183,187 ( 33.3%)
#       entailment: 183,416 ( 33.4%)
# Loading dev data from /Users/akashmurali/Documents/NLP/project/snli_1.0/snli_1.0_dev.jsonl...
# ✅ Loaded 10000 examples from dev split
#
# DEV SET:
#   Total examples: 10,000
#   Valid examples: 9,842
#   Invalid examples: 158
#   Label distribution:
#          neutral:  3,235 ( 32.9%)
#       entailment:  3,329 ( 33.8%)
#     contradiction:  3,278 ( 33.3%)
# Loading test data from /Users/akashmurali/Documents/NLP/project/snli_1.0/snli_1.0_test.jsonl...
# ✅ Loaded 10000 examples from test split
#
# TEST SET:
#   Total examples: 10,000
# ...
